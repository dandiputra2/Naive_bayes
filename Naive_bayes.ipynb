# %% [markdown]
# <a href="https://colab.research.google.com/github/dandiputra2/Naive_bayes/blob/main/Naive_bayes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#memasukan data latih
datalatih = pd.read_csv(".Data.csv")
datalatih.head()
#Prestasi Siswa = 1 == Ya 
#Prestasi Siswa = 2 == Tidak
#Prestasi Sekolah = 1 == Cukup
#Prestasi Sekolah = 2 == Baik
# Out:
#              Sekolah  Matematika  IPS  IPA  Prestasi Siswa  Prestasi Sekolah
# 0  SMA Islam Alazhar          92   86   85               1                 2
# 1       SMA 1 Negeri          90   82   85               2                 2
# 2      SMK Walisongo          93   87   92               2                 1
# 3   SMA Muhammadiyah          93   82   85               1                 1
# 4       SMA 2 Negeri          86   85   88               1                 2

# %%
datalatih.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Sekolah           7 non-null      object
#  1   Matematika        7 non-null      int64
#  2   IPS               7 non-null      int64
#  3   IPA               7 non-null      int64
#  4   Prestasi Siswa    7 non-null      int64
#  5   Prestasi Sekolah  7 non-null      int64
# dtypes: int64(5), object(1)
# memory usage: 464.0+ bytes

# %%
from sklearn.cluster import KMeans
#Memvisualkan persebaran data
plt.scatter(datalatih.Matematika, datalatih.Sekolah, s = 75, c = "c", marker = "o", alpha = 0.5)
plt.show()

# %%
x = datalatih.drop(["Sekolah"], axis=1)
x.head(11)
# Out:
#    Matematika  IPS  IPA  Prestasi Siswa  Prestasi Sekolah
# 0          92   86   85               1                 2
# 1          90   82   85               2                 2
# 2          93   87   92               2                 1
# 3          93   82   85               1                 1
# 4          86   85   88               1                 2
# 5          91   80   84               2                 2
# 6          80   88   90               2                 1

# %%
y = datalatih["Sekolah"]
y.head(11)
# Out:
# 0    SMA Islam Alazhar
# 1         SMA 1 Negeri
# 2        SMK Walisongo
# 3     SMA Muhammadiyah
# 4         SMA 2 Negeri
# 5        SMA 25 Negeri
# 6         SMA 3 Swasta
# Name: Sekolah, dtype: object
